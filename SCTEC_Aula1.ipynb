# %% [markdown]
# <a href="https://colab.research.google.com/github/LoesterBotelho/SCTEC/blob/main/SCTEC_Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variáveis

# %%
# Tipo de Variáveis
nome = "Loester"
idade = 32
altura = 1.82
gosta_de_ia = True # True or False

# %%
print(nome)
print(idade)
print(altura)
print(gosta_de_ia)

print(f"{nome} {idade} {altura} {gosta_de_ia}")
# Out:
# Loester
# 32
# 1.82
# True
# Loester 32 1.82 True
